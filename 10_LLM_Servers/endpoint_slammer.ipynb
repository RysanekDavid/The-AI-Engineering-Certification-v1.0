# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 8
#       4 model_endpoint = "accounts/fireworks/models/gpt-oss-20b"
#       5
#       6 llm = ChatFireworks(model=model_endpoint)
#       7
# ----> 8 response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
#       9 print(response.content)
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\langchain_fireworks\chat_models.py:840, in ChatFireworks._generate(self, messages, stop, run_manager, stream, **kwargs)
#     834 message_dicts, params = self._create_message_dicts(messages, stop)
#     835 params = {
#     836     **params,
#     837     **({"stream": stream} if stream is not None else {}),
#     838     **kwargs,
#     839 }
# --> 840 response = _completion_with_retry(
#     841     self, run_manager=run_manager, messages=message_dicts, **params
#     842 )
#     843 return self._create_chat_result(response)
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\langchain_fireworks\chat_models.py:497, in _completion_with_retry(llm, run_manager, **kwargs)
#     494         return _prepend_chunk(first, iterator)
#     495     return result
# --> 497 return _call()
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\tenacity\__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\langchain_fireworks\chat_models.py:479, in _completion_with_retry.<locals>._call()
#     476 @retry_decorator
#     477 def _call() -> Any:
#     478     try:
# --> 479         result = llm.client.create(**kwargs)
#     480     except httpx.HTTPStatusError as e:
#     481         _promote_http_status_error(e)
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\fireworks\client\chat_completion.py:41, in ChatCompletionV2.create(self, model, prompt_or_messages, request_timeout, stream, extra_headers, **kwargs)
#      32 def create(
#      33     self,
#      34     model,
#    (...)     39     **kwargs,
#      40 ):
# ---> 41     return super().create(
#      42         model,
#      43         prompt_or_messages,
#      44         request_timeout,
#      45         stream=stream,
#      46         client=self._client,
#      47         extra_headers=extra_headers,
#      48         **self._validate_kwargs(kwargs),
#      49     )
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\fireworks\client\base_completion.py:81, in BaseCompletion.create(cls, model, prompt_or_messages, request_timeout, stream, client, extra_headers, **kwargs)
#      73     return cls._create_streaming(
#      74         model,
#      75         request_timeout,
#    (...)     78         **kwargs,
#      79     )
#      80 else:
# ---> 81     return cls._create_non_streaming(
#      82         model,
#      83         request_timeout,
#      84         client=client,
#      85         extra_headers=extra_headers,
#      86         **kwargs,
#      87     )
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\fireworks\client\base_completion.py:180, in BaseCompletion._create_non_streaming(cls, model, request_timeout, client, extra_headers, **kwargs)
#     178 client = client or FireworksClient(request_timeout=request_timeout)
#     179 data = {"model": model, "stream": False, **kwargs}
# --> 180 response = client.post_request_non_streaming(
#     181     f"{client.base_url}/{cls.endpoint}",
#     182     data=data,
#     183     extra_headers=extra_headers,
#     184 )
#     185 return cls.response_class(**response)
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\fireworks\client\api_client.py:160, in FireworksClient.post_request_non_streaming(self, url, data, extra_headers)
#     153 def post_request_non_streaming(
#     154     self,
#     155     url: str,
#     156     data: Optional[Dict[str, Any]] = None,
#     157     extra_headers: Optional[Dict[str, str]] = None,
#     158 ) -> Dict[str, Any]:
#     159     response = self._client.post(url, json=data, headers=self._get_headers(extra_headers))
# --> 160     self._error_handling(response)
#     161     return response.json()
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\fireworks\client\api_client.py:124, in FireworksClient._error_handling(self, resp)
#     122 if resp.is_error:
#     123     resp.read()
# --> 124 self._raise_for_status(resp)
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\fireworks\client\api_client.py:113, in FireworksClient._raise_for_status(self, response)
#     102             error_type = "unknown_error"
#     103         return json.dumps(
#     104             {
#     105                 "error": {
#    (...)    110             }
#     111         )
# --> 113 self._raise_for(response.status_code, get_error_message)
#     114 response.raise_for_status()
#
# File c:\Git\The-AI-Engineering-Certification-v1.0\10_LLM_Servers\.venv\Lib\site-packages\fireworks\client\api_client.py:81, in FireworksClient._raise_for(self, status_code, error_message)
#      79     raise APITimeoutError(error_message())
#      80 elif status_code == 429:
# ---> 81     raise RateLimitError(error_message())
#      82 elif status_code == 500:
#      83     raise InternalServerError(error_message())
#
# RateLimitError: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-33c58bfa38e947b28b71ab7cfcd82c17"}

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 23 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-e84d45d343dd47d2b9bdee4accef8d29"}
# Request 14 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-24183947dd4e42e5be8cb786fd1ef0c1"}
# Request 7 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-eb28274c0fbb4b878887c27bd204ef6a"}
# Request 12 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-83241e9e45d046fc9cd5d425c9d44c79"}
# Request 19 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-1e61dae5cf144e72871a1ee7467747cd"}
# Response 20: A woodchuck would chuck roughly 700 pounds of wood—if a wood...
# Response 13: Ah, the classic tongue‑twister! According to folklore (and t...
# Response 18: A wood‑chuck (if it could actually chuck wood) is “measured”...
# Response 6: The classic tongue‑twister goes:
#
# > *“How much wood could ...
# Response 2: A classic tongue‑twister answer is that a woodchuck would mo...
# Response 1: The classic tongue‑twister doesn’t give a definitive answer—...
# Response 21: The classic tongue‑twister doesn’t actually have a scientifi...
# Response 17: That old tongue‑twister is more a piece of folklore than a p...
# Response 4: Ah, the classic tongue‑twister! 🎶 It’s always fun to see how...
# Response 8: The classic tongue‑twister goes:
# **“How much wood would a ...
# Response 24: Here’s a playful take on the old tongue‑twister:
#
# > **"How m...
# Response 3: ChatGPT: A woodchuck can chuck about 700 pounds of wood, acc...
# Response 11: That tongue‑twister has been the subject of both folklore an...
# Response 9: A woodchuck could chuck about 700 pounds (roughly 1 cubic me...
# Response 15: The classic tongue‑twister invites a playful answer, and the...
# Response 16: The classic tongue‑twister doesn’t actually have a scientifi...
# Response 5: If a wood‑chuck really had the knack for “chucking” wood, it...
# Response 22: The classic tongue‑twister goes: “How much wood would a wood...
# Response 10: Here are ten playful answers to the classic tongue‑twister:
# ...
