# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# That’s the old tongue‑twister you were probably humming! In reality, scientists have measured the burrowing activity of a North American woodchuck (aka the “ground squirrel”) and found that it can move roughly **5.5–7.5 cubic feet** of dirt in a single burrow—about **700–800 pounds** of soil. If you let that same tool‑drilling dirt haul turn into chuckable wood, you’d probably end up with a similar heft of wood, though it’s a bit of a stretch—because woodchucks aren’t wood‑cutting specialists. So, short answer: a woodchuck could *chuck* about as much as it can shove out of its burrow—roughly 700–800 pounds, give or take an extra log or two for good measure!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 14 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-d036364010d24abdaac71f042cab66fd"}
# Request 13 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-7891bca0726f40c4a732c7ad398c58c4"}
# Request 21 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-c58d29624c6541c782e778c8d56b3383"}
# Request 12 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-56d6982438214cb4bbd8200b4f60bbee"}
# Request 20 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-b3e529ae8c064a81babd25870ee422e4"}
# Request 4 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-5b08b2f8d27b44b39cd7f5725c055555"}
# Request 17 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-17d20f48d2354b739c279107e17fe580"}
# Response 10: As the old tongue‑twister goes, a woodchuck would “chuck” “a...
# Response 18: *According to the most popular estimate (thanks to the 1988 ...
# Response 3: About that—if a woodchuck could chuck wood, it would chuck “...
# Response 1: As the classic tongue‑twister goes, a woodchuck would chuck ...
# Response 9: Sure thing!
#
# > **“How much wood could a wood‑chuck chuck i...
# Response 7: Ah, the classic tongue‑twister! In truth, the question is me...
# Response 19: **Answer:**
# > *“A wood‑chuck would chuck as much wood as a...
# Response 23: That classic tongue‑twister has a playful answer rather than...
# Response 15: **Request 15**
#
# The classic tongue‑twister is truly a playfu...
# Response 2: Ah, the classic tongue‑twister!
# Over the years, many folks...
# Response 24: A classic tongue‑twister, and the answer is – well, it’s mor...
# Response 8: A woodchuck would chuck roughly **700 lb (≈ 320 kg) of wood*...
# Response 6: Here’s the classic take on the tongue‑twister — it’s more of...
# Response 11: **Short answer**
# > About **700–800 pounds** of wood—roughl...
# Response 5: **Short answer:**
# A *woodchuck* can theoretically chuck th...
# Response 16: That classic tongue‑twister is less a scientific query than ...
# Response 22: **Answer**
#
# In the tongue‑twister lore a woodchuck would “ch...
